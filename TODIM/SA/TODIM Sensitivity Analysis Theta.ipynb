# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
plt.rcParams["figure.dpi"] = 1000
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = '8'

# %%
ranking_data = pd.read_csv('theta_rankings.csv')
ranking_data
# Out:
#       Theta  CA  FR  DE  IT  JP  UK  USA
# 0       1.0   2   1   3   6   7   4    5
# 1       2.0   3   5   7   4   6   2    1
# 2       3.0   2   1   3   6   7   4    5
# 3       4.0   3   5   7   4   6   2    1
# 4       5.0   1   2   3   6   7   5    4
# ..      ...  ..  ..  ..  ..  ..  ..  ...
# 995   997.0   5   6   4   7   3   2    1
# 996   998.0   1   2   4   7   6   5    3
# 997   999.0   5   6   4   7   3   2    1
# 998  1000.0   1   2   4   7   6   5    3
# 999  1001.0   5   6   4   7   3   2    1
#
# [1000 rows x 8 columns]

# %%
just_ranks = ranking_data.drop('Theta', axis=1)
just_ranks
# Out:
#      CA  FR  DE  IT  JP  UK  USA
# 0     2   1   3   6   7   4    5
# 1     3   5   7   4   6   2    1
# 2     2   1   3   6   7   4    5
# 3     3   5   7   4   6   2    1
# 4     1   2   3   6   7   5    4
# ..   ..  ..  ..  ..  ..  ..  ...
# 995   5   6   4   7   3   2    1
# 996   1   2   4   7   6   5    3
# 997   5   6   4   7   3   2    1
# 998   1   2   4   7   6   5    3
# 999   5   6   4   7   3   2    1
#
# [1000 rows x 7 columns]

# %%
x = just_ranks.columns

plt.xticks(rotation='vertical')
plt.yticks(ticks=range(1, len(x) + 1))

plt.xlabel('Alternatives')
plt.ylabel('Rank')

for _, row in just_ranks.iterrows():
    plt.scatter(x=x, y=list(row), alpha=0.002, c='black')
